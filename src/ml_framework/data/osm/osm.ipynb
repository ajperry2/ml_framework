# %%
# !pip install git+https://github.com/HTenkanen/pyrosm.git@v0.6.2
# Out:
# Collecting git+https://github.com/HTenkanen/pyrosm.git@v0.6.2
#   Cloning https://github.com/HTenkanen/pyrosm.git (to revision v0.6.2) to /tmp/pip-req-build-66v4aa3e
#   Running command git clone --filter=blob:none --quiet https://github.com/HTenkanen/pyrosm.git /tmp/pip-req-build-66v4aa3e
#   Running command git checkout -q 2b9606034353606ab0e9bf59416826975703a172
#   Resolved https://github.com/HTenkanen/pyrosm.git to commit 2b9606034353606ab0e9bf59416826975703a172
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: python-rapidjson in /home/alan/miniconda3/envs/ml_framework/lib/python3.8/site-packages (from pyrosm==0.6.2) (1.17)
# Requirement already satisfied: setuptools>=18.0 in /home/alan/miniconda3/envs/ml_framework/lib/python3.8/site-packages (from pyrosm==0.6.2) (70.0.0)
# Requirement already satisfied: geopandas>=0.12.0 in /home/alan/miniconda3/envs/ml_framework/lib/python3.8/site-packages (from pyrosm==0.6.2) (0.13.2)
# Requirement already satisfied: shapely>=2.0.1 in /home/alan/miniconda3/envs/ml_framework/lib/python3.8/site-packages (from pyrosm==0.6.2) (2.0.4)
# Requirement already satisfied: cykhash in /home/alan/miniconda3/envs/ml_framework/lib/python3.8/site-packages (from pyrosm==0.6.2) (2.0.1)
# Requirement already satisfied: pyrobuf in /home/alan/miniconda3/envs/ml_framework/lib/python3.8/site-packages (from pyrosm==0.6.2) (0.9.3)
# INFO: pip is looking at multiple versions of pyrosm to determine which version is compatible with other requirements. This could take a while.
# ERROR: Package 'pyrosm' requires a different Python: 3.8.19 not in '>=3.9'

# %%
pip install matplotlib

# %%
from pyrosm import get_data
# Download data for the city of Helsinki
fp = get_data("Helsinki", directory="data")
print(fp)
# Out:
# /home/alan/Desktop/Projects/ml/ml_framework/data/Helsinki.osm.pbf

# %%
from pyrosm import OSM

osm = OSM(fp)

# %%
my_filter = {"building": ["residential", "retail"]}
buildings = osm.get_buildings(custom_filter=my_filter)

# Plot
title = "Filtered buildings: " + ", ".join(buildings["building"].unique())
ax = buildings.plot(column="building", cmap="RdBu", legend=True)
ax.set_title(title);

# %% [markdown]
# # TODO
#
# -----
#
# A function which gets information in a bounding box (which will be paired with an image)
