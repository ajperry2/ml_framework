# %%
import geopandas as gpd
import osmnx as ox
import numpy as np
import networkx as nx
import pandas as pd

# %matplotlib inline
ox.__version__
# turn response caching off
ox.config(use_cache=False)
# Out:
# /tmp/ipykernel_97506/427095536.py:10: FutureWarning: The `utils.config` function is deprecated and will be removed in the v2.0.0 release. Instead, use the `settings` module directly to configure a global setting's value. For example, `ox.settings.log_console=True`. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   ox.config(use_cache=False)

# %%
north, south, east, west = 37.79, 37.78, -122.41, -122.43
G = ox.graph_from_bbox(north, south, east, west, network_type="drive_service")
ox.plot_graph(G, node_color="r");
# Out:
# /tmp/ipykernel_97506/2494096988.py:2: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   G = ox.graph_from_bbox(north, south, east, west, network_type="drive_service")
# /tmp/ipykernel_97506/2494096988.py:2: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   G = ox.graph_from_bbox(north, south, east, west, network_type="drive_service")

# %%
G.to_directed().edges
# Out:
# OutMultiEdgeView([(65281835, 65281838, 0), (65281835, 65303554, 0), (65281838, 65281835, 0), (65285109, 5429030134, 0), (65285109, 65350752, 0), (65287111, 65317959, 0), (65287111, 65350760, 0), (65287128, 267456161, 0), (65287128, 5429030206, 0), (65292425, 65292428, 0), (65292425, 65314160, 0), (65292428, 65292425, 0), (65292428, 4018840066, 0), (65292717, 4018809930, 0), (65292717, 65292722, 0), (65292717, 5287186198, 0), (65292717, 5287186190, 0), (65292722, 65292717, 0), (65292734, 65303566, 0), (65295347, 65329111, 0), (65295347, 65295349, 0), (65295349, 65351407, 0), (65295349, 65295352, 0), (65295349, 65295347, 0), (65295352, 65295349, 0), (65295352, 65319030, 0), (65297976, 65297982, 0), (65297976, 65317951, 0), (65297982, 65297976, 0), (65299782, 65299784, 0), (65299782, 65314158, 0), (65299784, 65299782, 0), (65299784, 65292428, 0), (65303546, 612771497, 0), (65303546, 5429620704, 0), (65303548, 65319949, 0), (65303548, 65303550, 0), (65303550, 4018840066, 0), (65303550, 65303552, 0), (65303552, 65319956, 0), (65303552, 65303553, 0), (65303553, 65314166, 0), (65303553, 65281835, 0), (65303554, 10934196866, 0), (65303554, 65335810, 0), (65303556, 65327165, 0), (65303556, 258758548, 0), (65303556, 65327163, 0), (65303559, 65350331, 0), (65303559, 65303560, 0), (65303560, 65303561, 0), (65303560, 65335801, 0), (65303561, 65314183, 0), (65303561, 4014319583, 0), (65303566, 2220968863, 0), (65303566, 65319024, 0), (65303566, 65292734, 0), (65303566, 5429032423, 0), (65303689, 4061806118, 0), (65303689, 65352325, 0), (65303689, 65352321, 0), (65303692, 6386250949, 0), (65308264, 763026749, 0), (65308264, 65352321, 0), (65308268, 65308264, 0), (65308268, 65362154, 0), (65308270, 65373970, 0), (65308270, 65308268, 0), (65308272, 65308270, 0), (65308272, 65352330, 0), (65308278, 65308272, 0), (65308278, 8719605788, 0), (65308283, 8719605787, 0), (65308283, 65308278, 0), (65308283, 65327146, 0), (65308287, 9691602767, 0), (65308287, 65352344, 0), (65308289, 65285109, 0), (65308289, 65308287, 0), (65309532, 4018840042, 0), (65312401, 65312403, 0), (65312401, 65343962, 0), (65312403, 65312401, 0), (65314158, 10802171480, 0), (65314158, 65343963, 0), (65314160, 65299782, 0), (65314160, 65334123, 0), (65314161, 65292425, 0), (65314161, 65318894, 0), (65314163, 65303552, 0), (65314163, 65314161, 0), (65314166, 65314163, 0), (65314166, 65334133, 0), (65314171, 65354431, 0), (65314171, 65314166, 0), (65314173, 65327160, 0), (65314173, 65327163, 0), (65314173, 65314171, 0), (65314175, 9691602746, 0), (65314175, 65334139, 0), (65314180, 8602603653, 0), (65314180, 2220968866, 0), (65314183, 2220968838, 0), (65314183, 11843621900, 0), (65314183, 5429030209, 0), (65314187, 65319023, 0), (65314187, 684998736, 0), (65314187, 65319024, 0), (65314187, 5429030220, 0), (65314258, 4018809915, 0), (65314258, 65314261, 0), (65314258, 65352337, 0), (65314261, 65314258, 0), (65317949, 1580501206, 0), (65317951, 65334128, 0), (65317951, 1580501216, 0), (65317954, 65297976, 0), (65317954, 65333831, 0), (65317956, 65354423, 0), (65317956, 65317954, 0), (65317957, 65323354, 0), (65317957, 3013377978, 0), (65317957, 65317956, 0), (65317959, 9691602646, 0), (65317959, 65323342, 0), (65317961, 5429030201, 0), (65317961, 4886012764, 0), (65318891, 65318894, 0), (65318894, 65318891, 0), (65318894, 65334125, 0), (65319013, 5287186202, 0), (65319013, 65292722, 0), (65319013, 276546818, 0), (65319019, 5287385338, 0), (65319019, 9728390500, 0), (65319019, 65319021, 0), (65319019, 5287186202, 0), (65319021, 5287186927, 0), (65319021, 5848171332, 0), (65319021, 65319019, 0), (65319021, 5429030162, 0), (65319023, 258759674, 0), (65319023, 65338334, 0), (65319023, 65314187, 0), (65319024, 5429032427, 0), (65319024, 65303566, 0), (65319024, 65314187, 0), (65319027, 65319030, 0), (65319027, 5429032423, 0), (65319027, 11380826583, 0), (65319030, 65295352, 0), (65319030, 65319027, 0), (65319946, 65303546, 0), (65319949, 65319946, 0), (65319951, 65319949, 0), (65319951, ...

# %%
from pyrosm import get_data
# Download data for the city of Helsinki
import os
if not os.path.exists("data"):
    os.mkdir("data")
fp = get_data("Helsinki", directory="data")
print(fp)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from pyrosm import get_data
#       2 # Download data for the city of Helsinki
#       3 import os
#
# ModuleNotFoundError: No module named 'pyrosm'

# %%
from pyrosm import OSM

osm = OSM(fp)

# %%
my_filter = {"building": ["residential", "retail"]}
buildings = osm.get_buildings(custom_filter=my_filter)

# Plot
title = "Filtered buildings: " + ", ".join(buildings["building"].unique())
ax = buildings.plot(column="building", cmap="RdBu", legend=True)
ax.set_title(title);

# %% [markdown]
# # TODO
#
# -----
#
# A function which gets information in a bounding box (which will be paired with an image)

# %%
from pyrosm.data import sources
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from pyrosm.data import sources
#
# ModuleNotFoundError: No module named 'pyrosm'

# %%
from osm import OSMDataset

# %%
north, south, east, west = [ 48.1,47.1,-121.7,-122.6]
a = OSMDataset([north, south, east, west], 400)
# Out:
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# ...
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   graph = ox.graph_from_bbox(
# /home/alan/Desktop/code/ml_framework/src/ml_framework/data/osm/osm.py:96: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   graph = ox.graph_from_bbox(

# %%
#sat_img, graph = a[0]

# %%
ax = a.plot(0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 ax = a.plot(0)
#
# NameError: name 'a' is not defined

# %%
[*ax.get_xlim(),*ax.get_ylim()]
# Out:
# [-122.243557234, -122.147963866, 47.097419056, 47.202222144000004]

# %%
# Out:
# (47.097419056, 47.202222144000004)
