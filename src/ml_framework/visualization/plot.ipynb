# %%
import sys
sys.path.append("../..")
import numpy as np
from ml_framework.visualization import plot_groups, FigureArguments

x = np.linspace(0, 2 * np.pi, 400)
y = np.sin(x ** 2)
plot_groups([x, -x], [y, -y], ["x", "-x"], ["y","-y"], "gist_rainbow_r")

# %%
from PIL import Image

# %%
import sys
import numpy as np
sys.path.append("../..")
from ml_framework.visualization import FigureArguments, plot_images

# %%
array = np.random.randint(255, size=(400, 400, 1), dtype=np.uint8) * 0.2

plot_images(image_groups=[[array]],group_labels=["my group"])

# %%
array = np.random.randint(255, size=(400, 400, 3), dtype=np.uint8) * 0.2

plot_images(image_groups=[[array]],group_labels=["my group"])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
